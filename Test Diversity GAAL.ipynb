# %%
from trainers.gaaltrainer import GAALTrainer
import dill as pickle

# %% [markdown]
# ## GAAL

# %%
ls = [0.0001, 0.001, 0.01, 0.1, 1]
for ll in ls:
    # GAAL Example - train and test on mnist 5 & 7
    classifier_acc = []
    classifier_nsamples = []
    for _ in range(10):
        gaal = GAALTrainer(traindatasettype='cifar10', testdatasettype='cifar10', 
                        generatorpath='./gans/cifar10-dcgan/generator_model_1500.h5', 
                        oraclepath='./oracles/cifar10ha.h5', 
                        n_samples_end=350, threshold=1e-8, 
                        start_samples=50, latent_dim=100, diversity='avgdist', L = ll)
        classifier_acc.append(gaal.learner_acc_history)
        classifier_nsamples.append(gaal.n_samples)

    # Save results to pickle
    result_gaal = [f'GAAL train and test on CIFAR10 with Diversity, L = {ll}', classifier_acc, classifier_nsamples, gaal.x_train_end, gaal.y_train_end]
    with open(f'./results/result_gaal_cifar10_d_{ll}.pkl', 'wb') as file:
        pickle.dump(result_gaal, file)
# Out:
# Training and testing with cifar10
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Classifier Accuracy Start: 0.736
# Generating latents and adding new samples to labelled set.
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# added 1
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# added 2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# touch2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Assignments\DSA5204\Project\Test Diversity GAAL.ipynb Cell 3' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Assignments/DSA5204/Project/Test%20Diversity%20GAAL.ipynb#ch0000005?line=4'>5</a> classifier_nsamples = []
#       <a href='vscode-notebook-cell:/d%3A/Assignments/DSA5204/Project/Test%20Diversity%20GAAL.ipynb#ch0000005?line=5'>6</a> for _ in range(10):
# ----> <a href='vscode-notebook-cell:/d%3A/Assignments/DSA5204/Project/Test%20Diversity%20GAAL.ipynb#ch0000005?line=6'>7</a>     gaal = GAALTrainer(traindatasettype='cifar10', testdatasettype='cifar10',
#       <a href='vscode-notebook-cell:/d%3A/Assignments/DSA5204/Project/Test%20Diversity%20GAAL.ipynb#ch0000005?line=7'>8</a>                     generatorpath='./gans/cifar10-dcgan/generator_model_1500.h5',
#       <a href='vscode-notebook-cell:/d%3A/Assignments/DSA5204/Project/Test%20Diversity%20GAAL.ipynb#ch0000005?line=8'>9</a>                     oraclepath='./oracles/cifar10ha.h5',
#      <a href='vscode-notebook-cell:/d%3A/Assignments/DSA5204/Project/Test%20Diversity%20GAAL.ipynb#ch0000005?line=9'>10</a>                     n_samples_end=350, threshold=1e-8,
#      <a href='vscode-notebook-cell:/d%3A/Assignments/DSA5204/Project/Test%20Diversity%20GAAL.ipynb#ch0000005?line=10'>11</a>                     start_samples=50, latent_dim=100)
#      <a href='vscode-notebook-cell:/d%3A/Assignments/DSA5204/Project/Test%20Diversity%20GAAL.ipynb#ch0000005?line=11'>12</a>     classifier_acc.append(gaal.learner_acc_history)
#      <a href='vscode-notebook-cell:/d%3A/Assignments/DSA5204/Project/Test%20Diversity%20GAAL.ipynb#ch0000005?line=12'>13</a>     classifier_nsamples.append(gaal.n_samples)
#
# File d:\Assignments\DSA5204\Project\trainers\gaaltrainer.py:109, in GAALTrainer.__init__(self, traindatasettype, testdatasettype, generatorpath, oraclepath, n_samples_end, threshold, start_samples, latent_dim, diversity, L)
#     <a href='file:///d%3A/Assignments/DSA5204/Project/trainers/gaaltrainer.py?line=106'>107</a> self.generator = self.loadgenerator(generatorpath)
#     <a href='file:///d%3A/Assignments/DSA5204/Project/trainers/gaaltrainer.py?line=107'>108</a> self.oracle = self.loadoracle(oraclepath)
# --> <a href='file:///d%3A/Assignments/DSA5204/Project/trainers/gaaltrainer.py?line=108'>109</a> self.x_train_end, self.y_train_end, self.learner_acc_history, self.n_samples = self.traingaal(n_samples_end, self.x_train, self.y_train, self.x_test, self.y_test)
#
# File d:\Assignments\DSA5204\Project\trainers\gaaltrainer.py:245, in GAALTrainer.traingaal(self, n_samples_end, x_train, y_train, x_test, y_test)
#     <a href='file:///d%3A/Assignments/DSA5204/Project/trainers/gaaltrainer.py?line=241'>242</a>             loss = tf.norm(dot) - self.L * dd
#     <a href='file:///d%3A/Assignments/DSA5204/Project/trainers/gaaltrainer.py?line=243'>244</a>     # Calculate gradients with respect to every trainable variable
# --> <a href='file:///d%3A/Assignments/DSA5204/Project/trainers/gaaltrainer.py?line=244'>245</a>     grad = tape.gradient(loss, z)
#     <a href='file:///d%3A/Assignments/DSA5204/Project/trainers/gaaltrainer.py?line=246'>247</a>     opt.apply_gradients(zip([grad], [z]))
#     <a href='file:///d%3A/Assignments/DSA5204/Project/trainers/gaaltrainer.py?line=248'>249</a> zt = z.numpy()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\backprop.py:1081, in GradientTape.gradient(self, target, sources, output_gradients, unconnected_gradients)
#    <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/backprop.py?line=1076'>1077</a> if output_gradients is not None:
#    <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/backprop.py?line=1077'>1078</a>   output_gradients = [None if x is None else ops.convert_to_tensor(x)
#    <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/backprop.py?line=1078'>1079</a>                       for x in nest.flatten(output_gradients)]
# -> <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/backprop.py?line=1080'>1081</a> flat_grad = imperative_grad.imperative_grad(
#    <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/backprop.py?line=1081'>1082</a>     self._tape,
#    <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/backprop.py?line=1082'>1083</a>     flat_targets,
#    <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/backprop.py?line=1083'>1084</a>     flat_sources,
#    <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/backprop.py?line=1084'>1085</a>     output_gradients=output_gradients,
#    <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/backprop.py?line=1085'>1086</a>     sources_raw=flat_sources_raw,
#    <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/backprop.py?line=1086'>1087</a>     unconnected_gradients=unconnected_gradients)
#    <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/backprop.py?line=1088'>1089</a> if not self._persistent:
#    <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/backprop.py?line=1089'>1090</a>   # Keep track of watched variables before setting tape to None
#    <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/backprop.py?line=1090'>1091</a>   self._watched_variables = self._tape.watched_variables()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\imperative_grad.py:67, in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/imperative_grad.py?line=62'>63</a> except ValueError:
#      <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/imperative_grad.py?line=63'>64</a>   raise ValueError(
#      <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/imperative_grad.py?line=64'>65</a>       "Unknown value for unconnected_gradients: %r" % unconnected_gradients)
# ---> <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/imperative_grad.py?line=66'>67</a> return pywrap_tfe.TFE_Py_TapeGradient(
#      <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/imperative_grad.py?line=67'>68</a>     tape._tape,  # pylint: disable=protected-access
#      <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/imperative_grad.py?line=68'>69</a>     target,
#      <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/imperative_grad.py?line=69'>70</a>     sources,
#      <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/imperative_grad.py?line=70'>71</a>     output_gradients,
#      <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/imperative_grad.py?line=71'>72</a>     sources_raw,
#      <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/imperative_grad.py?line=72'>73</a>     compat.as_str(unconnected_gradients.value))
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\backprop.py:156, in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices, forward_pass_name_scope)
#     <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/backprop.py?line=153'>154</a>     gradient_name_scope += forward_pass_name_scope + "/"
#     <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/backprop.py?line=154'>155</a>   with ops.name_scope(gradient_name_scope):
# --> <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/backprop.py?line=155'>156</a>     return grad_fn(mock_op, *out_grads)
#     <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/backprop.py?line=156'>157</a> else:
#     <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/backprop.py?line=157'>158</a>   return grad_fn(mock_op, *out_grads)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\ops\nn_grad.py:577, in _Conv2DGrad(op, grad)
#     <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/nn_grad.py?line=567'>568</a> shape_0, shape_1 = array_ops.shape_n([op.inputs[0], op.inputs[1]])
#     <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/nn_grad.py?line=569'>570</a> # We call the gen_nn_ops backprop functions instead of nn_ops backprop
#     <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/nn_grad.py?line=570'>571</a> # functions for performance reasons in Eager mode. gen_nn_ops functions take a
#     <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/nn_grad.py?line=571'>572</a> # `explicit_paddings` parameter, but nn_ops functions do not. So if we were
#     <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/nn_grad.py?line=572'>573</a> # to use the nn_ops functions, we would have to convert `padding` and
#     <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/nn_grad.py?line=573'>574</a> # `explicit_paddings` into a single `padding` parameter, increasing overhead
#     <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/nn_grad.py?line=574'>575</a> # in Eager mode.
#     <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/nn_grad.py?line=575'>576</a> return [
# --> <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/nn_grad.py?line=576'>577</a>     gen_nn_ops.conv2d_backprop_input(
#     <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/nn_grad.py?line=577'>578</a>         shape_0,
#     <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/nn_grad.py?line=578'>579</a>         op.inputs[1],
#     <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/nn_grad.py?line=579'>580</a>         grad,
#     <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/nn_grad.py?line=580'>581</a>         dilations=dilations,
#     <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/nn_grad.py?line=581'>582</a>         strides=strides,
#     <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/nn_grad.py?line=582'>583</a>         padding=padding,
#     <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/nn_grad.py?line=583'>584</a>         explicit_paddings=explicit_paddings,
#     <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/nn_grad.py?line=584'>585</a>         use_cudnn_on_gpu=use_cudnn_on_gpu,
#     <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/nn_grad.py?line=585'>586</a>         data_format=data_format),
#     <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/nn_grad.py?line=586'>587</a>     gen_nn_ops.conv2d_backprop_filter(
#     <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/nn_grad.py?line=587'>588</a>         op.inputs[0],
#     <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/nn_grad.py?line=588'>589</a>         shape_1,
#     <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/nn_grad.py?line=589'>590</a>         grad,
#     <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/nn_grad.py?line=590'>591</a>         dilations=dilations,
#     <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/nn_grad.py?line=591'>592</a>         strides=strides,
#     <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/nn_grad.py?line=592'>593</a>         padding=padding,
#     <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/nn_grad.py?line=593'>594</a>         explicit_paddings=explicit_paddings,
#     <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/nn_grad.py?line=594'>595</a>         use_cudnn_on_gpu=use_cudnn_on_gpu,
#     <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/nn_grad.py?line=595'>596</a>         data_format=data_format)
#     <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/nn_grad.py?line=596'>597</a> ]
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\ops\gen_nn_ops.py:1239, in conv2d_backprop_input(input_sizes, filter, out_backprop, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name)
#    <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/gen_nn_ops.py?line=1236'>1237</a> if tld.is_eager:
#    <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/gen_nn_ops.py?line=1237'>1238</a>   try:
# -> <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/gen_nn_ops.py?line=1238'>1239</a>     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/gen_nn_ops.py?line=1239'>1240</a>       _ctx, "Conv2DBackpropInput", name, input_sizes, filter, out_backprop,
#    <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/gen_nn_ops.py?line=1240'>1241</a>       "strides", strides, "use_cudnn_on_gpu", use_cudnn_on_gpu, "padding",
#    <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/gen_nn_ops.py?line=1241'>1242</a>       padding, "explicit_paddings", explicit_paddings, "data_format",
#    <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/gen_nn_ops.py?line=1242'>1243</a>       data_format, "dilations", dilations)
#    <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/gen_nn_ops.py?line=1243'>1244</a>     return _result
#    <a href='file:///c%3A/Users/Shaunn/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/ops/gen_nn_ops.py?line=1244'>1245</a>   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
