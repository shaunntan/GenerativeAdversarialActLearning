# %%
import numpy as np
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Reshape, Flatten, Conv2D, Conv2DTranspose, LeakyReLU, Dropout, BatchNormalization, ReLU
from matplotlib import pyplot as plt
import tensorflow as tf
##WGAN-additional
from keras import backend
from keras.constraints import Constraint

# %%
def loaddata(datasettype):
    if datasettype == 'mnist':
        (x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
        x_train = (x_train[(y_train == 5) | (y_train == 7),]- 127.5) / 127.5
        x_train = np.expand_dims(x_train, axis=3)
        y_train = y_train[(y_train == 5) | (y_train == 7)]
        y_train = np.where(y_train == 5, 0, 1).reshape((-1,1))

        x_test = (x_test[(y_test == 5) | (y_test == 7),]- 127.5) / 127.5
        x_test = np.expand_dims(x_test, axis=3)
        y_test = y_test[(y_test == 5) | (y_test == 7)]
        y_test = np.where(y_test == 5, 0, 1).reshape((-1,1))

    elif datasettype == 'cifar10':
        (x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
        y_train = np.squeeze(y_train)
        y_test = np.squeeze(y_test)
        x_train = (x_train[(y_train == 1) | (y_train == 7),]- 127.5) / 127.5
        y_train = y_train[(y_train == 1) | (y_train == 7)]
        y_train = np.where(y_train == 1, 0, 1).reshape((-1,1))

        x_test = (x_test[(y_test == 1) | (y_test == 7),]- 127.5) / 127.5
        y_test = y_test[(y_test == 1) | (y_test == 7)]
        y_test = np.where(y_test == 1, 0, 1).reshape((-1,1))

    return x_train, y_train, x_test, y_test

### WGAN - Wasserstein loss
def wasserstein_loss(y_true, y_pred):
    return backend.mean(y_true * y_pred)

### WGAN - Critic Weight Clipping
# clip model weights to a given hypercube
class ClipConstraint(Constraint):
    # set clip value when initialized
    def __init__(self, clip_value):
        self.clip_value = clip_value
 
    # clip model weights to hypercube
    def __call__(self, weights):
        return backend.clip(weights, -self.clip_value, self.clip_value)
 
    # get the config
    def get_config(self):
        return {'clip_value': self.clip_value}

def makediscriminator(input_shape):
    # define weight clipping constraint
    const = ClipConstraint(0.01)
    
    model = Sequential()
    ### WGAN-add clipping kernel_contraint
    model.add(Conv2D(64, (5,5), strides=(2, 2), padding='same', input_shape = input_shape, kernel_constraint=const))
    model.add(LeakyReLU())
    model.add(Dropout(0.3))
    ### WGAN-add clipping kernel_contraint
    model.add(Conv2D(128, (5,5), strides=(2, 2), padding='same', kernel_constraint=const))
    model.add(LeakyReLU(alpha=0.3))
    model.add(Dropout(0.3))

    model.add(Flatten())
    ### WGAN-Change to linear activation
    model.add(Dense(1, activation='linear'))
    ###WGAN-Use RMSPROP
    opt = RMSprop(lr=0.00005)
    ### WGAN-Wasserstein Loss
    model.compile(loss=wasserstein_loss, optimizer=opt, metrics=['accuracy'])
    return model

def makegenerator(datasettype, latent_dim):
    if datasettype == 'mnist':
        channels = 1
        finalsize = 28
    elif datasettype == 'cifar10':
        channels = 3
        finalsize = 32

    model = Sequential()
    if datasettype == 'mnist':

        model.add(Dense(7*7*256, use_bias=False, input_shape=(100,)))
        model.add(BatchNormalization())
        model.add(LeakyReLU())

        model.add(Reshape((7, 7, 256)))

        model.add(Conv2DTranspose(128, (5, 5), strides=(1, 1), padding='same', use_bias=False))
        model.add(BatchNormalization())
        model.add(LeakyReLU())

        model.add(Conv2DTranspose(64, (5, 5), strides=(2, 2), padding='same', use_bias=False))
        model.add(BatchNormalization())
        model.add(LeakyReLU())

        model.add(Conv2DTranspose(1, (5, 5), strides=(2, 2), padding='same', use_bias=False, activation='tanh'))

    elif datasettype == 'cifar10':
        n_nodes = 256 * 4 * 4
        model.add(Dense(n_nodes, input_dim=latent_dim))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Reshape((4, 4, 256)))
        # upsample to 8x8
        model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
        model.add(LeakyReLU(alpha=0.2))
        # upsample to 16x16
        model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
        model.add(LeakyReLU(alpha=0.2))
        # upsample to 32x32
        model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
        model.add(LeakyReLU(alpha=0.2))
        # output layer
        model.add(Conv2D(3, (3,3), activation='tanh', padding='same'))
    return model

def makegan(g_model, d_model):
    # set discriminator to not trainable
    d_model.trainable = False
    # setup gan
    model = Sequential()
    model.add(g_model)
    model.add(d_model)
    ###WGAN-Use RMSPROP
    opt = RMSprop(lr=0.00005)
    model.compile(loss=wasserstein_loss, optimizer=opt)
    return model

def gen_real(dataset, n_samples):
    # generate random indices for subsampling
    idx = np.random.randint(0, dataset.shape[0], n_samples)
    x = dataset[idx]
    ### for WGAN generate class labels == -1 for real
    y = -np.ones((n_samples, 1))
    return x, y

def gen_fake(g_model, latent_dim, n_samples):
    # generate points in latent space
    x_input = get_latent(latent_dim, n_samples)
    # predict outputs
    X = g_model.predict(x_input)
    ### for WGAN generate class labels == 1 for fake
    y = np.ones((n_samples, 1))
    return X, y

def get_latent(latent_dim, n_samples):
    # generate latent input points
    x_input = np.random.randn(latent_dim * n_samples)
    # reshape to fit network
    x_input = x_input.reshape(n_samples, latent_dim)
    return x_input

def save_plot(savepath, examples, epoch, n=4):
    # plot images
    print(examples.shape)
    print(np.min(examples))
    print(np.max(examples))
    for i in range(n * n):
        # define subplot
        plt.subplot(n, n, 1 + i)
        # turn off axis
        plt.axis('off')
        # plot raw pixel data
        plt.imshow(examples[i].astype('uint8'))
    # save plot to file
    filename = 'Generated_plot_e%03d.png' % (epoch+1)
    plt.savefig(savepath + filename)
    plt.close()

def performance(savepath, epoch, g_model, d_model, dataset, latent_dim, n_samples=100):
    # prepare real samples
    X_real, y_real = gen_real(dataset, n_samples)
    # evaluate discriminator on real examples
    _, acc_real = d_model.evaluate(X_real, y_real, verbose=0)
    # prepare fake examples
    x_fake, y_fake = gen_fake(g_model, latent_dim, n_samples)
    # evaluate discriminator on fake examples
    _, acc_fake = d_model.evaluate(x_fake, y_fake, verbose=0)
    # summarize discriminator performance
    print('Performance test> Accuracy real: %.0f%%, fake: %.0f%%' % (acc_real*100, acc_fake*100))
    # save plot
    fakeplot = (x_fake * 127.5) + 127.5

    save_plot(savepath, fakeplot, epoch)
    # save the generator model tile file
    g_filename = 'generator_model_%03d.h5' % (epoch + 1)
    g_model.save(savepath + g_filename)
    d_filename = 'discriminator_model_%03d.h5' % (epoch + 1)
    d_model.save(savepath + d_filename)

def train(datasettype, savepath, x_train, latent_dim, n_critic=5, n_epochs=200, batchsize=256, retries = 5, max_loss_increase_epochs = 10):
    batch_per_epoch = int(x_train.shape[0] / batchsize)
    half_batch = int(batchsize / 2)
    # manually enumerate epochs
    
    for r in range(retries):
        print(f'Attempt:{r+1}')
        d_model = makediscriminator(x_train.shape[1:])
        g_model = makegenerator(datasettype, latent_dim)
        gan_model = makegan(g_model, d_model)

        d_loss_real = []
        d_loss_fake = []
        d_acc_real = []
        d_acc_fake = []

        g_loss = []
        g_loss_epoch = []
        g_loss_inc_counter = 0
        for i in range(n_epochs):
            print(f'Epoch: {i+1}')
            # enumerate batches over the training set
            for j in range(batch_per_epoch):
                
                ### WGAN-update critic more times than generator
                for _ in range(n_critic):
                    # get randomly selected 'real' samples
                    X_real, y_real = gen_real(x_train, half_batch)
                    # generate 'fake' examples
                    X_fake, y_fake = gen_fake(g_model, latent_dim, half_batch)
                    # update discriminator model weights
                    d_l_real, d_a_real = d_model.train_on_batch(X_real, y_real)
                    d_l_fake, d_a_fake = d_model.train_on_batch(X_fake, y_fake)
                # prepare points in latent space as input for the generator
                X_gan = get_latent(latent_dim, batchsize)
                ###WGAN- minust labels
                y_gan = -np.ones((batchsize, 1))
                # update the generator via the discriminator's error
                g_l = gan_model.train_on_batch(X_gan, y_gan)
                # summarize loss on this batch
                d_loss_real.append(d_l_real)
                d_loss_fake.append(d_l_fake)
                d_acc_real.append(d_a_real)
                d_acc_fake.append(d_a_fake)
                g_loss.append(g_l)
            print('Try:%d, Epoch:%d, D_Loss_Real=%.3f, D_Loss_Fake=%.3f, D_Acc_Real=%.3f, D_Acc_Fake=%.3f, GAN_Loss=%.3f\n' % (r+1, i+1, d_l_real, d_l_fake, d_a_real, d_a_fake, g_l))
            g_loss_epoch.append(g_l)
            if len(g_loss_epoch) >= 2:
                if g_loss_epoch[-1] >  g_loss_epoch[-2]:
                    g_loss_inc_counter += 1
                    print(f'Generator loss increased for {g_loss_inc_counter} epochs.')
                elif g_loss_epoch[-1] <  g_loss_epoch[-2]:
                    g_loss_inc_counter = 0

            if g_loss_inc_counter == max_loss_increase_epochs:
                print(f'Try: {r+1} failed to train. Restarting training')
                break
    #         evaluate the model performance, sometimes
            if (i+1) % 20 == 0:
                performance(savepath, i, g_model, d_model, x_train, latent_dim)

            if i == n_epochs - 1:
                return g_model, d_model, gan_model, d_loss_real, d_loss_fake, d_acc_real, d_acc_fake, g_loss

    # reach here if fail to train
    print("Training Stopped...")
    return g_model, d_model, gan_model, d_loss_real, d_loss_fake, d_acc_real, d_acc_fake, g_loss

# %%
x_train, y_train, x_test, y_test = loaddata('mnist')

# %%
savepath = './testwgan/'

# %%
g_model, d_model, gan_model, d_loss_real, d_loss_fake, d_acc_real, d_acc_fake, g_loss = \
train('mnist', savepath, x_train, latent_dim=100, n_critic=5, n_epochs=200, batchsize=256, retries = 5, max_loss_increase_epochs = 10000)
# Out:
# Attempt:1
# Epoch: 1
# Try:1, Epoch:1, D_Loss_Real=-87.470, D_Loss_Fake=9.400, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-83.938
#
# Epoch: 2
# Try:1, Epoch:2, D_Loss_Real=-236.885, D_Loss_Fake=63.586, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-275.404
#
# Epoch: 3
# Try:1, Epoch:3, D_Loss_Real=-301.134, D_Loss_Fake=208.418, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-365.851
#
# Epoch: 4
# Try:1, Epoch:4, D_Loss_Real=-294.337, D_Loss_Fake=297.251, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-355.912
#
# Generator loss increased for 1 epochs.
# Epoch: 5
# Try:1, Epoch:5, D_Loss_Real=-218.614, D_Loss_Fake=253.253, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-267.006
#
# Generator loss increased for 2 epochs.
# Epoch: 6
# Try:1, Epoch:6, D_Loss_Real=-129.149, D_Loss_Fake=154.281, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-154.167
#
# Generator loss increased for 3 epochs.
# Epoch: 7
# Try:1, Epoch:7, D_Loss_Real=-62.671, D_Loss_Fake=71.844, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-70.409
#
# Generator loss increased for 4 epochs.
# Epoch: 8
# Try:1, Epoch:8, D_Loss_Real=-28.651, D_Loss_Fake=30.373, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-31.371
#
# Generator loss increased for 5 epochs.
# Epoch: 9
# Try:1, Epoch:9, D_Loss_Real=-20.085, D_Loss_Fake=17.555, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-26.104
#
# Generator loss increased for 6 epochs.
# Epoch: 10
# Try:1, Epoch:10, D_Loss_Real=-27.949, D_Loss_Fake=20.313, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-44.507
#
# Epoch: 11
# Try:1, Epoch:11, D_Loss_Real=-34.684, D_Loss_Fake=33.349, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-65.469
#
# Epoch: 12
# Try:1, Epoch:12, D_Loss_Real=-20.230, D_Loss_Fake=23.974, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-33.860
#
# Generator loss increased for 1 epochs.
# Epoch: 13
# Try:1, Epoch:13, D_Loss_Real=-16.754, D_Loss_Fake=12.781, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-10.930
#
# Generator loss increased for 2 epochs.
# Epoch: 14
# Try:1, Epoch:14, D_Loss_Real=-21.587, D_Loss_Fake=22.203, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-23.356
#
# Epoch: 15
# Try:1, Epoch:15, D_Loss_Real=-17.444, D_Loss_Fake=18.545, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-17.930
#
# Generator loss increased for 1 epochs.
# Epoch: 16
# Try:1, Epoch:16, D_Loss_Real=-12.841, D_Loss_Fake=13.524, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-13.004
#
# Generator loss increased for 2 epochs.
# Epoch: 17
# Try:1, Epoch:17, D_Loss_Real=-11.277, D_Loss_Fake=11.507, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-11.032
#
# Generator loss increased for 3 epochs.
# Epoch: 18
# Try:1, Epoch:18, D_Loss_Real=-10.097, D_Loss_Fake=10.314, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-9.849
#
# Generator loss increased for 4 epochs.
# Epoch: 19
# Try:1, Epoch:19, D_Loss_Real=-7.738, D_Loss_Fake=8.132, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-7.672
#
# Generator loss increased for 5 epochs.
# Epoch: 20
# Try:1, Epoch:20, D_Loss_Real=-6.109, D_Loss_Fake=6.395, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-6.007
#
# Generator loss increased for 6 epochs.
# Performance test> Accuracy real: 0%, fake: 100%
# (100, 28, 28, 1)
# 0.0
# 255.0
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 21
# Try:1, Epoch:21, D_Loss_Real=-4.521, D_Loss_Fake=4.771, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-4.499
#
# Generator loss increased for 7 epochs.
# Epoch: 22
# Try:1, Epoch:22, D_Loss_Real=-3.358, D_Loss_Fake=3.464, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-3.275
#
# Generator loss increased for 8 epochs.
# Epoch: 23
# Try:1, Epoch:23, D_Loss_Real=-2.339, D_Loss_Fake=2.415, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-2.260
#
# Generator loss increased for 9 epochs.
# Epoch: 24
# Try:1, Epoch:24, D_Loss_Real=-1.761, D_Loss_Fake=1.828, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.762
#
# Generator loss increased for 10 epochs.
# Epoch: 25
# Try:1, Epoch:25, D_Loss_Real=-1.563, D_Loss_Fake=1.602, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.537
#
# Generator loss increased for 11 epochs.
# Epoch: 26
# Try:1, Epoch:26, D_Loss_Real=-1.509, D_Loss_Fake=1.503, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.448
#
# Generator loss increased for 12 epochs.
# Epoch: 27
# Try:1, Epoch:27, D_Loss_Real=-1.422, D_Loss_Fake=1.445, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.382
#
# Generator loss increased for 13 epochs.
# Epoch: 28
# Try:1, Epoch:28, D_Loss_Real=-1.427, D_Loss_Fake=1.410, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.366
#
# Generator loss increased for 14 epochs.
# Epoch: 29
# Try:1, Epoch:29, D_Loss_Real=-1.416, D_Loss_Fake=1.404, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.340
#
# Generator loss increased for 15 epochs.
# Epoch: 30
# Try:1, Epoch:30, D_Loss_Real=-1.391, D_Loss_Fake=1.390, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.311
#
# Generator loss increased for 16 epochs.
# Epoch: 31
# Try:1, Epoch:31, D_Loss_Real=-1.354, D_Loss_Fake=1.352, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.275
#
# Generator loss increased for 17 epochs.
# Epoch: 32
# Try:1, Epoch:32, D_Loss_Real=-1.418, D_Loss_Fake=1.410, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.341
#
# Epoch: 33
# Try:1, Epoch:33, D_Loss_Real=-1.438, D_Loss_Fake=1.408, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.338
#
# Generator loss increased for 1 epochs.
# Epoch: 34
# Try:1, Epoch:34, D_Loss_Real=-1.415, D_Loss_Fake=1.389, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.299
#
# Generator loss increased for 2 epochs.
# Epoch: 35
# Try:1, Epoch:35, D_Loss_Real=-1.427, D_Loss_Fake=1.406, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.337
#
# Epoch: 36
# Try:1, Epoch:36, D_Loss_Real=-1.436, D_Loss_Fake=1.378, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.320
#
# Generator loss increased for 1 epochs.
# Epoch: 37
# Try:1, Epoch:37, D_Loss_Real=-1.433, D_Loss_Fake=1.390, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.313
#
# Generator loss increased for 2 epochs.
# Epoch: 38
# Try:1, Epoch:38, D_Loss_Real=-1.427, D_Loss_Fake=1.395, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.318
#
# Epoch: 39
# Try:1, Epoch:39, D_Loss_Real=-1.414, D_Loss_Fake=1.394, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.307
#
# Generator loss increased for 1 epochs.
# Epoch: 40
# Try:1, Epoch:40, D_Loss_Real=-1.431, D_Loss_Fake=1.338, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.285
#
# Generator loss increased for 2 epochs.
# Performance test> Accuracy real: 0%, fake: 100%
# (100, 28, 28, 1)
# 0.0
# 255.0
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 41
# Try:1, Epoch:41, D_Loss_Real=-1.437, D_Loss_Fake=1.368, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.317
#
# Epoch: 42
# Try:1, Epoch:42, D_Loss_Real=-1.436, D_Loss_Fake=1.397, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.319
#
# Epoch: 43
# Try:1, Epoch:43, D_Loss_Real=-1.420, D_Loss_Fake=1.356, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.309
#
# Generator loss increased for 1 epochs.
# Epoch: 44
# Try:1, Epoch:44, D_Loss_Real=-1.437, D_Loss_Fake=1.420, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.351
#
# Epoch: 45
# Try:1, Epoch:45, D_Loss_Real=-1.437, D_Loss_Fake=1.424, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.328
#
# Generator loss increased for 1 epochs.
# Epoch: 46
# Try:1, Epoch:46, D_Loss_Real=-1.407, D_Loss_Fake=1.396, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.318
#
# Generator loss increased for 2 epochs.
# Epoch: 47
# Try:1, Epoch:47, D_Loss_Real=-1.407, D_Loss_Fake=1.348, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.288
#
# Generator loss increased for 3 epochs.
# Epoch: 48
# Try:1, Epoch:48, D_Loss_Real=-1.392, D_Loss_Fake=1.340, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.285
#
# Generator loss increased for 4 epochs.
# Epoch: 49
# Try:1, Epoch:49, D_Loss_Real=-1.353, D_Loss_Fake=1.323, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.286
#
# Epoch: 50
# Try:1, Epoch:50, D_Loss_Real=-1.323, D_Loss_Fake=1.311, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.263
#
# Generator loss increased for 1 epochs.
# Epoch: 51
# Try:1, Epoch:51, D_Loss_Real=-1.319, D_Loss_Fake=1.304, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.237
#
# Generator loss increased for 2 epochs.
# Epoch: 52
# Try:1, Epoch:52, D_Loss_Real=-1.274, D_Loss_Fake=1.255, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.203
#
# Generator loss increased for 3 epochs.
# Epoch: 53
# Try:1, Epoch:53, D_Loss_Real=-1.253, D_Loss_Fake=1.231, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.192
#
# Generator loss increased for 4 epochs.
# Epoch: 54
# Try:1, Epoch:54, D_Loss_Real=-1.222, D_Loss_Fake=1.219, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.179
#
# Generator loss increased for 5 epochs.
# Epoch: 55
# Try:1, Epoch:55, D_Loss_Real=-1.244, D_Loss_Fake=1.174, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.189
#
# Epoch: 56
# Try:1, Epoch:56, D_Loss_Real=-1.200, D_Loss_Fake=1.184, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.124
#
# Generator loss increased for 1 epochs.
# Epoch: 57
# Try:1, Epoch:57, D_Loss_Real=-1.175, D_Loss_Fake=1.194, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.092
#
# Generator loss increased for 2 epochs.
# Epoch: 58
# Try:1, Epoch:58, D_Loss_Real=-1.160, D_Loss_Fake=1.153, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.075
#
# Generator loss increased for 3 epochs.
# Epoch: 59
# Try:1, Epoch:59, D_Loss_Real=-1.145, D_Loss_Fake=1.130, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.099
#
# Epoch: 60
# Try:1, Epoch:60, D_Loss_Real=-1.109, D_Loss_Fake=1.090, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.036
#
# Generator loss increased for 1 epochs.
# Performance test> Accuracy real: 0%, fake: 100%
# (100, 28, 28, 1)
# 0.0
# 255.0
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 61
# Try:1, Epoch:61, D_Loss_Real=-1.120, D_Loss_Fake=1.118, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.050
#
# Epoch: 62
# Try:1, Epoch:62, D_Loss_Real=-1.094, D_Loss_Fake=1.078, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.037
#
# Generator loss increased for 1 epochs.
# Epoch: 63
# Try:1, Epoch:63, D_Loss_Real=-1.093, D_Loss_Fake=1.069, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.013
#
# Generator loss increased for 2 epochs.
# Epoch: 64
# Try:1, Epoch:64, D_Loss_Real=-1.053, D_Loss_Fake=1.078, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-1.009
#
# Generator loss increased for 3 epochs.
# Epoch: 65
# Try:1, Epoch:65, D_Loss_Real=-1.041, D_Loss_Fake=1.013, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-0.986
#
# Generator loss increased for 4 epochs.
# Epoch: 66
# Try:1, Epoch:66, D_Loss_Real=-1.041, D_Loss_Fake=1.006, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-0.971
#
# Generator loss increased for 5 epochs.
# Epoch: 67
# Try:1, Epoch:67, D_Loss_Real=-1.006, D_Loss_Fake=0.998, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-0.937
#
# Generator loss increased for 6 epochs.
# Epoch: 68
# Try:1, Epoch:68, D_Loss_Real=-0.989, D_Loss_Fake=0.989, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-0.939
#
# Epoch: 69
# Try:1, Epoch:69, D_Loss_Real=-0.964, D_Loss_Fake=0.970, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-0.919
#
# Generator loss increased for 1 epochs.
# Epoch: 70
# Try:1, Epoch:70, D_Loss_Real=-0.976, D_Loss_Fake=0.950, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-0.921
#
# Epoch: 71
# Try:1, Epoch:71, D_Loss_Real=-0.955, D_Loss_Fake=0.952, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-0.886
#
# Generator loss increased for 1 epochs.
# Epoch: 72
# Try:1, Epoch:72, D_Loss_Real=-0.922, D_Loss_Fake=0.926, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-0.852
#
# Generator loss increased for 2 epochs.
# Epoch: 73
# Try:1, Epoch:73, D_Loss_Real=-0.914, D_Loss_Fake=0.912, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-0.853
#
# Epoch: 74
# Try:1, Epoch:74, D_Loss_Real=-0.878, D_Loss_Fake=0.883, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-0.844
#
# Generator loss increased for 1 epochs.
# Epoch: 75
# Try:1, Epoch:75, D_Loss_Real=-0.869, D_Loss_Fake=0.869, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-0.835
#
# Generator loss increased for 2 epochs.
# Epoch: 76
# Try:1, Epoch:76, D_Loss_Real=-0.861, D_Loss_Fake=0.869, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-0.813
#
# Generator loss increased for 3 epochs.
# Epoch: 77
# Try:1, Epoch:77, D_Loss_Real=-0.880, D_Loss_Fake=0.843, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-0.794
#
# Generator loss increased for 4 epochs.
# Epoch: 78
# Try:1, Epoch:78, D_Loss_Real=-0.869, D_Loss_Fake=0.860, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-0.804
#
# Epoch: 79
# Try:1, Epoch:79, D_Loss_Real=-0.837, D_Loss_Fake=0.857, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-0.793
#
# Generator loss increased for 1 epochs.
# Epoch: 80
# Try:1, Epoch:80, D_Loss_Real=-0.831, D_Loss_Fake=0.843, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-0.783
#
# Generator loss increased for 2 epochs.
# Performance test> Accuracy real: 0%, fake: 100%
# (100, 28, 28, 1)
# 0.0
# 254.99982
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 81
# Try:1, Epoch:81, D_Loss_Real=-0.828, D_Loss_Fake=0.810, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-0.766
#
# Generator loss increased for 3 epochs.
# Epoch: 82
# Try:1, Epoch:82, D_Loss_Real=-0.832, D_Loss_Fake=0.837, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-0.768
#
# Epoch: 83
# Try:1, Epoch:83, D_Loss_Real=-0.819, D_Loss_Fake=0.828, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-0.776
#
# Epoch: 84
# Try:1, Epoch:84, D_Loss_Real=-0.808, D_Loss_Fake=0.776, D_Acc_Real=0.000, D_Acc_Fake=0.992, GAN_Loss=-0.729
#
# Generator loss increased for 1 epochs.
# Epoch: 85
# Try:1, Epoch:85, D_Loss_Real=-0.811, D_Loss_Fake=0.788, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-0.758
#
# Epoch: 86
# Try:1, Epoch:86, D_Loss_Real=-0.775, D_Loss_Fake=0.784, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-0.753
#
# Generator loss increased for 1 epochs.
# Epoch: 87
# Try:1, Epoch:87, D_Loss_Real=-0.779, D_Loss_Fake=0.775, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-0.730
#
# Generator loss increased for 2 epochs.
# Epoch: 88
# Try:1, Epoch:88, D_Loss_Real=-0.768, D_Loss_Fake=0.769, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-0.711
#
# Generator loss increased for 3 epochs.
# Epoch: 89
# Try:1, Epoch:89, D_Loss_Real=-0.759, D_Loss_Fake=0.762, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-0.708
#
# Generator loss increased for 4 epochs.
# Epoch: 90
# Try:1, Epoch:90, D_Loss_Real=-0.744, D_Loss_Fake=0.737, D_Acc_Real=0.000, D_Acc_Fake=0.992, GAN_Loss=-0.698
#
# Generator loss increased for 5 epochs.
# Epoch: 91
# Try:1, Epoch:91, D_Loss_Real=-0.753, D_Loss_Fake=0.739, D_Acc_Real=0.000, D_Acc_Fake=1.000, GAN_Loss=-0.699
#
# Epoch: 92
# Try:1, Epoch:92, D_Loss_Real=-0.748, D_Loss_Fake=0.737, D_Acc_Real=0.000, D_Acc_Fake=0.984, GAN_Loss=-0.685
#
# Generator loss increased for 1 epochs.
# Epoch: 93
# Try:1, Epoch:93, D_Loss_Real=-0.730, D_Loss_Fake=0.727, D_Acc_Real=0.000, D_Acc_Fake=0.992, GAN_Loss=-0.685
#
# Epoch: 94
# Try:1, Epoch:94, D_Loss_Real=-0.736, D_Loss_Fake=0.708, D_Acc_Real=0.000, D_Acc_Fake=0.961, GAN_Loss=-0.661
#
# Generator loss increased for 1 epochs.
# Epoch: 95
# Try:1, Epoch:95, D_Loss_Real=-0.731, D_Loss_Fake=0.691, D_Acc_Real=0.000, D_Acc_Fake=0.961, GAN_Loss=-0.673
#
# Epoch: 96
# Try:1, Epoch:96, D_Loss_Real=-0.726, D_Loss_Fake=0.723, D_Acc_Real=0.000, D_Acc_Fake=0.984, GAN_Loss=-0.675
#
# Epoch: 97
# Try:1, Epoch:97, D_Loss_Real=-0.709, D_Loss_Fake=0.731, D_Acc_Real=0.000, D_Acc_Fake=0.984, GAN_Loss=-0.649
#
# Generator loss increased for 1 epochs.
# Epoch: 98
# Try:1, Epoch:98, D_Loss_Real=-0.714, D_Loss_Fake=0.687, D_Acc_Real=0.000, D_Acc_Fake=0.984, GAN_Loss=-0.668
#
# Epoch: 99
# Try:1, Epoch:99, D_Loss_Real=-0.717, D_Loss_Fake=0.676, D_Acc_Real=0.000, D_Acc_Fake=0.961, GAN_Loss=-0.653
#
# Generator loss increased for 1 epochs.
# Epoch: 100
# Try:1, Epoch:100, D_Loss_Real=-0.686, D_Loss_Fake=0.690, D_Acc_Real=0.000, D_Acc_Fake=0.953, GAN_Loss=-0.647
#
# Generator loss increased for 2 epochs.
# Performance test> Accuracy real: 0%, fake: 100%
# (100, 28, 28, 1)
# 0.0
# 254.99991
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 101
# Try:1, Epoch:101, D_Loss_Real=-0.685, D_Loss_Fake=0.694, D_Acc_Real=0.000, D_Acc_Fake=0.977, GAN_Loss=-0.661
#
# Epoch: 102
# Try:1, Epoch:102, D_Loss_Real=-0.695, D_Loss_Fake=0.686, D_Acc_Real=0.000, D_Acc_Fake=0.977, GAN_Loss=-0.651
#
# Generator loss increased for 1 epochs.
# Epoch: 103
# Try:1, Epoch:103, D_Loss_Real=-0.703, D_Loss_Fake=0.675, D_Acc_Real=0.000, D_Acc_Fake=0.961, GAN_Loss=-0.643
#
# Generator loss increased for 2 epochs.
# Epoch: 104
# Try:1, Epoch:104, D_Loss_Real=-0.675, D_Loss_Fake=0.683, D_Acc_Real=0.000, D_Acc_Fake=0.984, GAN_Loss=-0.647
#
# Epoch: 105
# Try:1, Epoch:105, D_Loss_Real=-0.687, D_Loss_Fake=0.683, D_Acc_Real=0.000, D_Acc_Fake=0.977, GAN_Loss=-0.641
#
# Generator loss increased for 1 epochs.
# Epoch: 106
# Try:1, Epoch:106, D_Loss_Real=-0.675, D_Loss_Fake=0.665, D_Acc_Real=0.000, D_Acc_Fake=0.961, GAN_Loss=-0.632
#
# Generator loss increased for 2 epochs.
# Epoch: 107
# Try:1, Epoch:107, D_Loss_Real=-0.680, D_Loss_Fake=0.670, D_Acc_Real=0.000, D_Acc_Fake=0.953, GAN_Loss=-0.634
#
# Epoch: 108
# Try:1, Epoch:108, D_Loss_Real=-0.685, D_Loss_Fake=0.655, D_Acc_Real=0.000, D_Acc_Fake=0.938, GAN_Loss=-0.611
#
# Generator loss increased for 1 epochs.
# Epoch: 109
# Try:1, Epoch:109, D_Loss_Real=-0.689, D_Loss_Fake=0.648, D_Acc_Real=0.000, D_Acc_Fake=0.875, GAN_Loss=-0.600
#
# Generator loss increased for 2 epochs.
# Epoch: 110
# Try:1, Epoch:110, D_Loss_Real=-0.673, D_Loss_Fake=0.670, D_Acc_Real=0.000, D_Acc_Fake=0.961, GAN_Loss=-0.630
#
# Epoch: 111
# Try:1, Epoch:111, D_Loss_Real=-0.662, D_Loss_Fake=0.672, D_Acc_Real=0.000, D_Acc_Fake=0.992, GAN_Loss=-0.621
#
# Generator loss increased for 1 epochs.
# Epoch: 112
# Try:1, Epoch:112, D_Loss_Real=-0.667, D_Loss_Fake=0.640, D_Acc_Real=0.000, D_Acc_Fake=0.930, GAN_Loss=-0.602
#
# Generator loss increased for 2 epochs.
# Epoch: 113
# Try:1, Epoch:113, D_Loss_Real=-0.652, D_Loss_Fake=0.653, D_Acc_Real=0.000, D_Acc_Fake=0.938, GAN_Loss=-0.608
#
# Epoch: 114
# Try:1, Epoch:114, D_Loss_Real=-0.649, D_Loss_Fake=0.637, D_Acc_Real=0.000, D_Acc_Fake=0.945, GAN_Loss=-0.599
#
# Generator loss increased for 1 epochs.
# Epoch: 115
# Try:1, Epoch:115, D_Loss_Real=-0.628, D_Loss_Fake=0.615, D_Acc_Real=0.000, D_Acc_Fake=0.898, GAN_Loss=-0.580
#
# Generator loss increased for 2 epochs.
# Epoch: 116
# Try:1, Epoch:116, D_Loss_Real=-0.611, D_Loss_Fake=0.612, D_Acc_Real=0.000, D_Acc_Fake=0.852, GAN_Loss=-0.563
#
# Generator loss increased for 3 epochs.
# Epoch: 117
# Try:1, Epoch:117, D_Loss_Real=-0.639, D_Loss_Fake=0.606, D_Acc_Real=0.000, D_Acc_Fake=0.812, GAN_Loss=-0.589
#
# Epoch: 118
# Try:1, Epoch:118, D_Loss_Real=-0.643, D_Loss_Fake=0.632, D_Acc_Real=0.000, D_Acc_Fake=0.961, GAN_Loss=-0.593
#
# Epoch: 119
# Try:1, Epoch:119, D_Loss_Real=-0.609, D_Loss_Fake=0.613, D_Acc_Real=0.000, D_Acc_Fake=0.914, GAN_Loss=-0.562
#
# Generator loss increased for 1 epochs.
# Epoch: 120
# Try:1, Epoch:120, D_Loss_Real=-0.604, D_Loss_Fake=0.588, D_Acc_Real=0.000, D_Acc_Fake=0.859, GAN_Loss=-0.560
#
# Generator loss increased for 2 epochs.
# Performance test> Accuracy real: 0%, fake: 97%
# (100, 28, 28, 1)
# 0.0
# 254.99995
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 121
# Try:1, Epoch:121, D_Loss_Real=-0.596, D_Loss_Fake=0.581, D_Acc_Real=0.000, D_Acc_Fake=0.828, GAN_Loss=-0.548
#
# Generator loss increased for 3 epochs.
# Epoch: 122
# Try:1, Epoch:122, D_Loss_Real=-0.611, D_Loss_Fake=0.573, D_Acc_Real=0.000, D_Acc_Fake=0.781, GAN_Loss=-0.555
#
# Epoch: 123
# Try:1, Epoch:123, D_Loss_Real=-0.619, D_Loss_Fake=0.602, D_Acc_Real=0.000, D_Acc_Fake=0.852, GAN_Loss=-0.557
#
# Epoch: 124
# Try:1, Epoch:124, D_Loss_Real=-0.597, D_Loss_Fake=0.593, D_Acc_Real=0.000, D_Acc_Fake=0.852, GAN_Loss=-0.558
#
# Epoch: 125
# Try:1, Epoch:125, D_Loss_Real=-0.598, D_Loss_Fake=0.593, D_Acc_Real=0.000, D_Acc_Fake=0.883, GAN_Loss=-0.550
#
# Generator loss increased for 1 epochs.
# Epoch: 126
# Try:1, Epoch:126, D_Loss_Real=-0.607, D_Loss_Fake=0.594, D_Acc_Real=0.000, D_Acc_Fake=0.828, GAN_Loss=-0.534
#
# Generator loss increased for 2 epochs.
# Epoch: 127
# Try:1, Epoch:127, D_Loss_Real=-0.598, D_Loss_Fake=0.589, D_Acc_Real=0.000, D_Acc_Fake=0.820, GAN_Loss=-0.549
#
# Epoch: 128
# Try:1, Epoch:128, D_Loss_Real=-0.601, D_Loss_Fake=0.579, D_Acc_Real=0.000, D_Acc_Fake=0.766, GAN_Loss=-0.544
#
# Generator loss increased for 1 epochs.
# Epoch: 129
# Try:1, Epoch:129, D_Loss_Real=-0.606, D_Loss_Fake=0.588, D_Acc_Real=0.000, D_Acc_Fake=0.852, GAN_Loss=-0.564
#
# Epoch: 130
# Try:1, Epoch:130, D_Loss_Real=-0.604, D_Loss_Fake=0.591, D_Acc_Real=0.000, D_Acc_Fake=0.875, GAN_Loss=-0.562
#
# Generator loss increased for 1 epochs.
# Epoch: 131
# Try:1, Epoch:131, D_Loss_Real=-0.577, D_Loss_Fake=0.593, D_Acc_Real=0.000, D_Acc_Fake=0.875, GAN_Loss=-0.540
#
# Generator loss increased for 2 epochs.
# Epoch: 132
# Try:1, Epoch:132, D_Loss_Real=-0.584, D_Loss_Fake=0.591, D_Acc_Real=0.000, D_Acc_Fake=0.820, GAN_Loss=-0.521
#
# Generator loss increased for 3 epochs.
# Epoch: 133
# Try:1, Epoch:133, D_Loss_Real=-0.584, D_Loss_Fake=0.561, D_Acc_Real=0.000, D_Acc_Fake=0.750, GAN_Loss=-0.521
#
# Epoch: 134
# Try:1, Epoch:134, D_Loss_Real=-0.578, D_Loss_Fake=0.577, D_Acc_Real=0.000, D_Acc_Fake=0.797, GAN_Loss=-0.544
#
# Epoch: 135
# Try:1, Epoch:135, D_Loss_Real=-0.578, D_Loss_Fake=0.600, D_Acc_Real=0.000, D_Acc_Fake=0.898, GAN_Loss=-0.546
#
# Epoch: 136
# Try:1, Epoch:136, D_Loss_Real=-0.589, D_Loss_Fake=0.587, D_Acc_Real=0.000, D_Acc_Fake=0.883, GAN_Loss=-0.535
#
# Generator loss increased for 1 epochs.
# Epoch: 137
# Try:1, Epoch:137, D_Loss_Real=-0.575, D_Loss_Fake=0.581, D_Acc_Real=0.000, D_Acc_Fake=0.820, GAN_Loss=-0.533
#
# Generator loss increased for 2 epochs.
# Epoch: 138
# Try:1, Epoch:138, D_Loss_Real=-0.575, D_Loss_Fake=0.544, D_Acc_Real=0.000, D_Acc_Fake=0.719, GAN_Loss=-0.519
#
# Generator loss increased for 3 epochs.
# Epoch: 139
# Try:1, Epoch:139, D_Loss_Real=-0.562, D_Loss_Fake=0.581, D_Acc_Real=0.000, D_Acc_Fake=0.812, GAN_Loss=-0.537
#
# Epoch: 140
# Try:1, Epoch:140, D_Loss_Real=-0.575, D_Loss_Fake=0.561, D_Acc_Real=0.000, D_Acc_Fake=0.719, GAN_Loss=-0.526
#
# Generator loss increased for 1 epochs.
# Performance test> Accuracy real: 0%, fake: 74%
# (100, 28, 28, 1)
# 0.0
# 254.99994
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 141
# Try:1, Epoch:141, D_Loss_Real=-0.565, D_Loss_Fake=0.563, D_Acc_Real=0.000, D_Acc_Fake=0.727, GAN_Loss=-0.525
#
# Generator loss increased for 2 epochs.
# Epoch: 142
# Try:1, Epoch:142, D_Loss_Real=-0.566, D_Loss_Fake=0.567, D_Acc_Real=0.000, D_Acc_Fake=0.781, GAN_Loss=-0.519
#
# Generator loss increased for 3 epochs.
# Epoch: 143
# Try:1, Epoch:143, D_Loss_Real=-0.567, D_Loss_Fake=0.543, D_Acc_Real=0.000, D_Acc_Fake=0.648, GAN_Loss=-0.522
#
# Epoch: 144
# Try:1, Epoch:144, D_Loss_Real=-0.562, D_Loss_Fake=0.541, D_Acc_Real=0.000, D_Acc_Fake=0.648, GAN_Loss=-0.518
#
# Generator loss increased for 1 epochs.
# Epoch: 145
# Try:1, Epoch:145, D_Loss_Real=-0.557, D_Loss_Fake=0.552, D_Acc_Real=0.000, D_Acc_Fake=0.766, GAN_Loss=-0.518
#
# Generator loss increased for 2 epochs.
# Epoch: 146
# Try:1, Epoch:146, D_Loss_Real=-0.560, D_Loss_Fake=0.549, D_Acc_Real=0.000, D_Acc_Fake=0.719, GAN_Loss=-0.515
#
# Generator loss increased for 3 epochs.
# Epoch: 147
# Try:1, Epoch:147, D_Loss_Real=-0.542, D_Loss_Fake=0.543, D_Acc_Real=0.000, D_Acc_Fake=0.695, GAN_Loss=-0.501
#
# Generator loss increased for 4 epochs.
# Epoch: 148
# Try:1, Epoch:148, D_Loss_Real=-0.535, D_Loss_Fake=0.529, D_Acc_Real=0.000, D_Acc_Fake=0.625, GAN_Loss=-0.501
#
# Epoch: 149
# Try:1, Epoch:149, D_Loss_Real=-0.533, D_Loss_Fake=0.538, D_Acc_Real=0.000, D_Acc_Fake=0.719, GAN_Loss=-0.491
#
# Generator loss increased for 1 epochs.
# Epoch: 150
# Try:1, Epoch:150, D_Loss_Real=-0.536, D_Loss_Fake=0.527, D_Acc_Real=0.000, D_Acc_Fake=0.594, GAN_Loss=-0.504
#
# Epoch: 151
# Try:1, Epoch:151, D_Loss_Real=-0.558, D_Loss_Fake=0.525, D_Acc_Real=0.000, D_Acc_Fake=0.586, GAN_Loss=-0.480
#
# Generator loss increased for 1 epochs.
# Epoch: 152
# Try:1, Epoch:152, D_Loss_Real=-0.536, D_Loss_Fake=0.535, D_Acc_Real=0.000, D_Acc_Fake=0.672, GAN_Loss=-0.496
#
# Epoch: 153
# Try:1, Epoch:153, D_Loss_Real=-0.563, D_Loss_Fake=0.545, D_Acc_Real=0.000, D_Acc_Fake=0.688, GAN_Loss=-0.504
#
# Epoch: 154
# Try:1, Epoch:154, D_Loss_Real=-0.534, D_Loss_Fake=0.549, D_Acc_Real=0.000, D_Acc_Fake=0.664, GAN_Loss=-0.504
#
# Generator loss increased for 1 epochs.
# Epoch: 155
# Try:1, Epoch:155, D_Loss_Real=-0.536, D_Loss_Fake=0.529, D_Acc_Real=0.000, D_Acc_Fake=0.703, GAN_Loss=-0.510
#
# Epoch: 156
# Try:1, Epoch:156, D_Loss_Real=-0.528, D_Loss_Fake=0.518, D_Acc_Real=0.000, D_Acc_Fake=0.602, GAN_Loss=-0.500
#
# Generator loss increased for 1 epochs.
# Epoch: 157
# Try:1, Epoch:157, D_Loss_Real=-0.546, D_Loss_Fake=0.525, D_Acc_Real=0.000, D_Acc_Fake=0.570, GAN_Loss=-0.499
#
# Generator loss increased for 2 epochs.
# Epoch: 158
# Try:1, Epoch:158, D_Loss_Real=-0.527, D_Loss_Fake=0.524, D_Acc_Real=0.000, D_Acc_Fake=0.641, GAN_Loss=-0.485
#
# Generator loss increased for 3 epochs.
# Epoch: 159
# Try:1, Epoch:159, D_Loss_Real=-0.542, D_Loss_Fake=0.523, D_Acc_Real=0.000, D_Acc_Fake=0.633, GAN_Loss=-0.501
#
# Epoch: 160
# Try:1, Epoch:160, D_Loss_Real=-0.526, D_Loss_Fake=0.521, D_Acc_Real=0.000, D_Acc_Fake=0.594, GAN_Loss=-0.492
#
# Generator loss increased for 1 epochs.
# Performance test> Accuracy real: 0%, fake: 38%
# (100, 28, 28, 1)
# 0.0
# 254.99977
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 161
# Try:1, Epoch:161, D_Loss_Real=-0.545, D_Loss_Fake=0.535, D_Acc_Real=0.000, D_Acc_Fake=0.680, GAN_Loss=-0.477
#
# Generator loss increased for 2 epochs.
# Epoch: 162
# Try:1, Epoch:162, D_Loss_Real=-0.519, D_Loss_Fake=0.520, D_Acc_Real=0.000, D_Acc_Fake=0.594, GAN_Loss=-0.489
#
# Epoch: 163
# Try:1, Epoch:163, D_Loss_Real=-0.520, D_Loss_Fake=0.515, D_Acc_Real=0.000, D_Acc_Fake=0.547, GAN_Loss=-0.486
#
# Generator loss increased for 1 epochs.
# Epoch: 164
# Try:1, Epoch:164, D_Loss_Real=-0.530, D_Loss_Fake=0.510, D_Acc_Real=0.000, D_Acc_Fake=0.547, GAN_Loss=-0.473
#
# Generator loss increased for 2 epochs.
# Epoch: 165
# Try:1, Epoch:165, D_Loss_Real=-0.508, D_Loss_Fake=0.507, D_Acc_Real=0.000, D_Acc_Fake=0.547, GAN_Loss=-0.482
#
# Epoch: 166
# Try:1, Epoch:166, D_Loss_Real=-0.521, D_Loss_Fake=0.507, D_Acc_Real=0.000, D_Acc_Fake=0.547, GAN_Loss=-0.470
#
# Generator loss increased for 1 epochs.
# Epoch: 167
# Try:1, Epoch:167, D_Loss_Real=-0.508, D_Loss_Fake=0.488, D_Acc_Real=0.000, D_Acc_Fake=0.453, GAN_Loss=-0.463
#
# Generator loss increased for 2 epochs.
# Epoch: 168
# Try:1, Epoch:168, D_Loss_Real=-0.503, D_Loss_Fake=0.495, D_Acc_Real=0.000, D_Acc_Fake=0.523, GAN_Loss=-0.456
#
# Generator loss increased for 3 epochs.
# Epoch: 169
# Try:1, Epoch:169, D_Loss_Real=-0.505, D_Loss_Fake=0.486, D_Acc_Real=0.000, D_Acc_Fake=0.469, GAN_Loss=-0.470
#
# Epoch: 170
# Try:1, Epoch:170, D_Loss_Real=-0.507, D_Loss_Fake=0.497, D_Acc_Real=0.000, D_Acc_Fake=0.477, GAN_Loss=-0.464
#
# Generator loss increased for 1 epochs.
# Epoch: 171
# Try:1, Epoch:171, D_Loss_Real=-0.519, D_Loss_Fake=0.494, D_Acc_Real=0.000, D_Acc_Fake=0.492, GAN_Loss=-0.464
#
# Generator loss increased for 2 epochs.
# Epoch: 172
# Try:1, Epoch:172, D_Loss_Real=-0.503, D_Loss_Fake=0.502, D_Acc_Real=0.000, D_Acc_Fake=0.523, GAN_Loss=-0.470
#
# Epoch: 173
# Try:1, Epoch:173, D_Loss_Real=-0.498, D_Loss_Fake=0.496, D_Acc_Real=0.000, D_Acc_Fake=0.461, GAN_Loss=-0.451
#
# Generator loss increased for 1 epochs.
# Epoch: 174
# Try:1, Epoch:174, D_Loss_Real=-0.496, D_Loss_Fake=0.486, D_Acc_Real=0.000, D_Acc_Fake=0.406, GAN_Loss=-0.457
#
# Epoch: 175
# Try:1, Epoch:175, D_Loss_Real=-0.499, D_Loss_Fake=0.492, D_Acc_Real=0.000, D_Acc_Fake=0.477, GAN_Loss=-0.457
#
# Generator loss increased for 1 epochs.
# Epoch: 176
# Try:1, Epoch:176, D_Loss_Real=-0.504, D_Loss_Fake=0.483, D_Acc_Real=0.000, D_Acc_Fake=0.414, GAN_Loss=-0.451
#
# Generator loss increased for 2 epochs.
# Epoch: 177
# Try:1, Epoch:177, D_Loss_Real=-0.487, D_Loss_Fake=0.490, D_Acc_Real=0.000, D_Acc_Fake=0.453, GAN_Loss=-0.459
#
# Epoch: 178
# Try:1, Epoch:178, D_Loss_Real=-0.488, D_Loss_Fake=0.472, D_Acc_Real=0.000, D_Acc_Fake=0.383, GAN_Loss=-0.447
#
# Generator loss increased for 1 epochs.
# Epoch: 179
# Try:1, Epoch:179, D_Loss_Real=-0.488, D_Loss_Fake=0.497, D_Acc_Real=0.000, D_Acc_Fake=0.531, GAN_Loss=-0.449
#
# Epoch: 180
# Try:1, Epoch:180, D_Loss_Real=-0.496, D_Loss_Fake=0.493, D_Acc_Real=0.000, D_Acc_Fake=0.484, GAN_Loss=-0.455
#
# Performance test> Accuracy real: 0%, fake: 17%
# (100, 28, 28, 1)
# 0.0
# 254.99948
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 181
# Try:1, Epoch:181, D_Loss_Real=-0.474, D_Loss_Fake=0.479, D_Acc_Real=0.000, D_Acc_Fake=0.398, GAN_Loss=-0.436
#
# Generator loss increased for 1 epochs.
# Epoch: 182
# Try:1, Epoch:182, D_Loss_Real=-0.482, D_Loss_Fake=0.470, D_Acc_Real=0.000, D_Acc_Fake=0.312, GAN_Loss=-0.431
#
# Generator loss increased for 2 epochs.
# Epoch: 183
# Try:1, Epoch:183, D_Loss_Real=-0.484, D_Loss_Fake=0.475, D_Acc_Real=0.000, D_Acc_Fake=0.344, GAN_Loss=-0.448
#
# Epoch: 184
# Try:1, Epoch:184, D_Loss_Real=-0.507, D_Loss_Fake=0.479, D_Acc_Real=0.000, D_Acc_Fake=0.336, GAN_Loss=-0.459
#
# Epoch: 185
# Try:1, Epoch:185, D_Loss_Real=-0.483, D_Loss_Fake=0.473, D_Acc_Real=0.000, D_Acc_Fake=0.367, GAN_Loss=-0.460
#
# Epoch: 186
# Try:1, Epoch:186, D_Loss_Real=-0.486, D_Loss_Fake=0.489, D_Acc_Real=0.000, D_Acc_Fake=0.430, GAN_Loss=-0.450
#
# Generator loss increased for 1 epochs.
# Epoch: 187
# Try:1, Epoch:187, D_Loss_Real=-0.478, D_Loss_Fake=0.479, D_Acc_Real=0.000, D_Acc_Fake=0.398, GAN_Loss=-0.456
#
# Epoch: 188
# Try:1, Epoch:188, D_Loss_Real=-0.495, D_Loss_Fake=0.473, D_Acc_Real=0.000, D_Acc_Fake=0.383, GAN_Loss=-0.428
#
# Generator loss increased for 1 epochs.
# Epoch: 189
# Try:1, Epoch:189, D_Loss_Real=-0.497, D_Loss_Fake=0.487, D_Acc_Real=0.000, D_Acc_Fake=0.438, GAN_Loss=-0.449
#
# Epoch: 190
# Try:1, Epoch:190, D_Loss_Real=-0.479, D_Loss_Fake=0.468, D_Acc_Real=0.000, D_Acc_Fake=0.312, GAN_Loss=-0.454
#
# Epoch: 191
# Try:1, Epoch:191, D_Loss_Real=-0.492, D_Loss_Fake=0.461, D_Acc_Real=0.000, D_Acc_Fake=0.312, GAN_Loss=-0.444
#
# Generator loss increased for 1 epochs.
# Epoch: 192
# Try:1, Epoch:192, D_Loss_Real=-0.489, D_Loss_Fake=0.476, D_Acc_Real=0.000, D_Acc_Fake=0.367, GAN_Loss=-0.441
#
# Generator loss increased for 2 epochs.
# Epoch: 193
# Try:1, Epoch:193, D_Loss_Real=-0.483, D_Loss_Fake=0.480, D_Acc_Real=0.000, D_Acc_Fake=0.352, GAN_Loss=-0.440
#
# Generator loss increased for 3 epochs.
# Epoch: 194
# Try:1, Epoch:194, D_Loss_Real=-0.470, D_Loss_Fake=0.464, D_Acc_Real=0.000, D_Acc_Fake=0.336, GAN_Loss=-0.426
#
# Generator loss increased for 4 epochs.
# Epoch: 195
# Try:1, Epoch:195, D_Loss_Real=-0.466, D_Loss_Fake=0.471, D_Acc_Real=0.000, D_Acc_Fake=0.320, GAN_Loss=-0.437
#
# Epoch: 196
# Try:1, Epoch:196, D_Loss_Real=-0.465, D_Loss_Fake=0.467, D_Acc_Real=0.000, D_Acc_Fake=0.312, GAN_Loss=-0.429
#
# Generator loss increased for 1 epochs.
# Epoch: 197
# Try:1, Epoch:197, D_Loss_Real=-0.469, D_Loss_Fake=0.463, D_Acc_Real=0.000, D_Acc_Fake=0.273, GAN_Loss=-0.441
#
# Epoch: 198
# Try:1, Epoch:198, D_Loss_Real=-0.465, D_Loss_Fake=0.460, D_Acc_Real=0.000, D_Acc_Fake=0.289, GAN_Loss=-0.437
#
# Generator loss increased for 1 epochs.
# Epoch: 199
# Try:1, Epoch:199, D_Loss_Real=-0.472, D_Loss_Fake=0.458, D_Acc_Real=0.000, D_Acc_Fake=0.289, GAN_Loss=-0.430
#
# Generator loss increased for 2 epochs.
# Epoch: 200
# Try:1, Epoch:200, D_Loss_Real=-0.469, D_Loss_Fake=0.453, D_Acc_Real=0.000, D_Acc_Fake=0.258, GAN_Loss=-0.427
#
# Generator loss increased for 3 epochs.
# Performance test> Accuracy real: 0%, fake: 3%
# (100, 28, 28, 1)
# 0.0
# 254.99983
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
