# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt

# %%
def loaddata():
    (x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
    x_train = (x_train[(y_train == 5) | (y_train == 7),]- 127.5) / 127.5
    x_train = np.expand_dims(x_train, axis=3)
    y_train = y_train[(y_train == 5) | (y_train == 7)]
    y_train = np.where(y_train == 5, 0, 1).reshape((-1,1))

    x_test = (x_test[(y_test == 5) | (y_test == 7),]- 127.5) / 127.5
    x_test = np.expand_dims(x_test, axis=3)
    y_test = y_test[(y_test == 5) | (y_test == 7)]
    y_test = np.where(y_test == 5, 0, 1).reshape((-1,1))

    np.random.seed(0)
    rand_idx = np.random.choice(np.arange(x_train.shape[0]), size = 20, replace = False)
    x_train = x_train[rand_idx]
    y_train = y_train[rand_idx]

    return x_train, y_train, x_test, y_test

# %%
x_train, y_train, x_test, y_test = loaddata()

# %%
def trainsvc(xtrain, ytrain):
    x = np.squeeze(xtrain)
    xt = x.reshape((x.shape[0],-1))
    svc = SVC(kernel='linear', gamma=0.001).fit(xt, ytrain.ravel())
    return svc

# %%
def loadgenerator(generatorpath):
    generator = load_model(generatorpath)
    generator.trainable = False
    return generator

# %%
def loadoracle(oraclepath):
    oracle = load_model(oraclepath)
    oracle.trainable = False
    return oracle

# %%
generator = loadgenerator('./mnist/generator_model_100.h5')
oracle = loadoracle('./oracles/mnist57.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
def generatesamples(n_iter, x_train, y_train, x_test, y_test):
    
    x_test = np.squeeze(x_test)
    x_test = x_test.reshape((x_test.shape[0],-1))
    
    y_test = y_test.ravel()
    learner_acc = []
    
    for i in range(n_iter):
        print(f'Round {i+1}')
        # train an svc using the training set
        print(f'Updating SVC')
        svc = trainsvc(x_train, y_train)
        svc_preds = svc.predict(x_test)
        acc = accuracy_score(y_test, svc_preds)
        print(f'Learner Accuracy: {acc}')
        learner_acc.append(acc)
        
        w = svc.coef_
        b = svc.intercept_

        w = tf.cast(tf.reshape(tf.Variable(w), [-1]), tf.float32)
        b = tf.cast(tf.Variable(b), tf.float32)
        
        print(f'Generating latents')
        cnt = 0
        zs = []
        # perform gradient descent on SVC with random start and get 10 minimum points
        while cnt < 10:

            z = np.random.randn(100).reshape((1,-1))
            z = tf.Variable(z)

            for _ in range(100):
                with tf.GradientTape() as tape:
                    # Forward pass
                    tape.watch(z)
                    f = generator(z)
                    f = tf.reshape(f, [-1])
                    dot = tf.tensordot(f, w, 1) + b    
                    loss = (dot**2)

                # Calculate gradients with respect to every trainable variable
                grad = tape.gradient(loss, z)
                opt = tf.keras.optimizers.SGD()
                opt.apply_gradients(zip([grad], [z]))

            zs.append(z.numpy())
            cnt += 1
        
        print(f'Generating fake images using GAN')
        # take the 10 minimum points and generate 10 fake images
        zt = np.vstack(zs)
        gen = generator.predict(zt)

        # use oracle to predict the label of the generated pictures
        gen_3c = np.repeat(gen, 3, axis = 3)
        gen_3c_32 = (tf.image.resize(gen_3c, [32,32]) + 1)/2
        oracle_labels = np.squeeze(oracle.predict(gen_3c_32))
        
        print(f'Updating training set\n')
        # pick only the good generated images subject to threshold and add to training set
        threshold = 1e-7
        gen_good = gen[(oracle_labels < threshold) | (oracle_labels > 1-threshold)]
        gen_good_labels = oracle_labels[(oracle_labels < threshold) | (oracle_labels > 1-threshold)]
        gen_good_labels = np.round(gen_good_labels).astype(int)
        gen_good_labels = np.expand_dims(gen_good_labels, axis = -1)

        # append the good data to the labeled set
        x_train = np.concatenate((x_train, gen_good), axis = 0)
        y_train = np.concatenate((y_train, gen_good_labels), axis = 0)
    
    return x_train, y_train, learner_acc

# %%
a, b, acc = generatesamples(100, x_train, y_train, x_test, y_test)
plt.plot(acc)
# Out:
# Round 1
# Updating SVC
# Learner Accuracy: 0.9567708333333333
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 2
# Updating SVC
# Learner Accuracy: 0.9770833333333333
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 3
# Updating SVC
# Learner Accuracy: 0.9802083333333333
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 4
# Updating SVC
# Learner Accuracy: 0.9786458333333333
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 5
# Updating SVC
# Learner Accuracy: 0.9791666666666666
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 6
# Updating SVC
# Learner Accuracy: 0.9770833333333333
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 7
# Updating SVC
# Learner Accuracy: 0.9802083333333333
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 8
# Updating SVC
# Learner Accuracy: 0.9786458333333333
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 9
# Updating SVC
# Learner Accuracy: 0.9786458333333333
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 10
# Updating SVC
# Learner Accuracy: 0.9786458333333333
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 11
# Updating SVC
# Learner Accuracy: 0.9786458333333333
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 12
# Updating SVC
# Learner Accuracy: 0.9786458333333333
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 13
# Updating SVC
# Learner Accuracy: 0.9791666666666666
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 14
# Updating SVC
# Learner Accuracy: 0.9734375
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 15
# Updating SVC
# Learner Accuracy: 0.9729166666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 16
# Updating SVC
# Learner Accuracy: 0.9729166666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 17
# Updating SVC
# Learner Accuracy: 0.9734375
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 18
# Updating SVC
# Learner Accuracy: 0.9734375
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 19
# Updating SVC
# Learner Accuracy: 0.9734375
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 20
# Updating SVC
# Learner Accuracy: 0.9734375
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 21
# Updating SVC
# Learner Accuracy: 0.9744791666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 22
# Updating SVC
# Learner Accuracy: 0.9744791666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 23
# Updating SVC
# Learner Accuracy: 0.9744791666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 24
# Updating SVC
# Learner Accuracy: 0.9744791666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 25
# Updating SVC
# Learner Accuracy: 0.9744791666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 26
# Updating SVC
# Learner Accuracy: 0.9765625
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 27
# Updating SVC
# Learner Accuracy: 0.9765625
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 28
# Updating SVC
# Learner Accuracy: 0.9765625
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 29
# Updating SVC
# Learner Accuracy: 0.9765625
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 30
# Updating SVC
# Learner Accuracy: 0.9770833333333333
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 31
# Updating SVC
# Learner Accuracy: 0.9776041666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 32
# Updating SVC
# Learner Accuracy: 0.9739583333333334
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 33
# Updating SVC
# Learner Accuracy: 0.971875
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 34
# Updating SVC
# Learner Accuracy: 0.9744791666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 35
# Updating SVC
# Learner Accuracy: 0.9744791666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 36
# Updating SVC
# Learner Accuracy: 0.9744791666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 37
# Updating SVC
# Learner Accuracy: 0.9744791666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 38
# Updating SVC
# Learner Accuracy: 0.9744791666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 39
# Updating SVC
# Learner Accuracy: 0.9744791666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 40
# Updating SVC
# Learner Accuracy: 0.975
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 41
# Updating SVC
# Learner Accuracy: 0.975
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 42
# Updating SVC
# Learner Accuracy: 0.975
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 43
# Updating SVC
# Learner Accuracy: 0.9791666666666666
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 44
# Updating SVC
# Learner Accuracy: 0.9791666666666666
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 45
# Updating SVC
# Learner Accuracy: 0.9786458333333333
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 46
# Updating SVC
# Learner Accuracy: 0.9760416666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 47
# Updating SVC
# Learner Accuracy: 0.9755208333333333
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 48
# Updating SVC
# Learner Accuracy: 0.9755208333333333
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 49
# Updating SVC
# Learner Accuracy: 0.9755208333333333
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 50
# Updating SVC
# Learner Accuracy: 0.9755208333333333
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 51
# Updating SVC
# Learner Accuracy: 0.9755208333333333
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 52
# Updating SVC
# Learner Accuracy: 0.9755208333333333
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 53
# Updating SVC
# Learner Accuracy: 0.9755208333333333
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 54
# Updating SVC
# Learner Accuracy: 0.9755208333333333
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 55
# Updating SVC
# Learner Accuracy: 0.9755208333333333
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 56
# Updating SVC
# Learner Accuracy: 0.9744791666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 57
# Updating SVC
# Learner Accuracy: 0.9744791666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 58
# Updating SVC
# Learner Accuracy: 0.9744791666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 59
# Updating SVC
# Learner Accuracy: 0.9744791666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 60
# Updating SVC
# Learner Accuracy: 0.9744791666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 61
# Updating SVC
# Learner Accuracy: 0.9729166666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 62
# Updating SVC
# Learner Accuracy: 0.9729166666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 63
# Updating SVC
# Learner Accuracy: 0.9729166666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 64
# Updating SVC
# Learner Accuracy: 0.9729166666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 65
# Updating SVC
# Learner Accuracy: 0.9729166666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 66
# Updating SVC
# Learner Accuracy: 0.9729166666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 67
# Updating SVC
# Learner Accuracy: 0.9723958333333333
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 68
# Updating SVC
# Learner Accuracy: 0.9744791666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 69
# Updating SVC
# Learner Accuracy: 0.9744791666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 70
# Updating SVC
# Learner Accuracy: 0.9744791666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 71
# Updating SVC
# Learner Accuracy: 0.9744791666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 72
# Updating SVC
# Learner Accuracy: 0.9770833333333333
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 73
# Updating SVC
# Learner Accuracy: 0.9770833333333333
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 74
# Updating SVC
# Learner Accuracy: 0.9770833333333333
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 75
# Updating SVC
# Learner Accuracy: 0.9770833333333333
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 76
# Updating SVC
# Learner Accuracy: 0.9770833333333333
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 77
# Updating SVC
# Learner Accuracy: 0.9770833333333333
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 78
# Updating SVC
# Learner Accuracy: 0.9770833333333333
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 79
# Updating SVC
# Learner Accuracy: 0.9770833333333333
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 80
# Updating SVC
# Learner Accuracy: 0.9770833333333333
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 81
# Updating SVC
# Learner Accuracy: 0.9817708333333334
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 82
# Updating SVC
# Learner Accuracy: 0.9817708333333334
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 83
# Updating SVC
# Learner Accuracy: 0.9807291666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 84
# Updating SVC
# Learner Accuracy: 0.9807291666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 85
# Updating SVC
# Learner Accuracy: 0.9807291666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 86
# Updating SVC
# Learner Accuracy: 0.9807291666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 87
# Updating SVC
# Learner Accuracy: 0.9807291666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 88
# Updating SVC
# Learner Accuracy: 0.9807291666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 89
# Updating SVC
# Learner Accuracy: 0.9807291666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 90
# Updating SVC
# Learner Accuracy: 0.9807291666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 91
# Updating SVC
# Learner Accuracy: 0.9807291666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 92
# Updating SVC
# Learner Accuracy: 0.9807291666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 93
# Updating SVC
# Learner Accuracy: 0.9807291666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 94
# Updating SVC
# Learner Accuracy: 0.9807291666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 95
# Updating SVC
# Learner Accuracy: 0.9807291666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 96
# Updating SVC
# Learner Accuracy: 0.9822916666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 97
# Updating SVC
# Learner Accuracy: 0.9822916666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 98
# Updating SVC
# Learner Accuracy: 0.9822916666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 99
# Updating SVC
# Learner Accuracy: 0.9822916666666667
# Generating latents
# Generating fake images using GAN
# Updating training set
#
# Round 100
# Updating SVC
# Learner Accuracy: 0.9822916666666667
# Generating latents
# Generating fake images using GAN
# Updating training set

# %%
plt.figure(figsize=(10,30))

for i in range(a.shape[0]):
    plt.subplot(int(a.shape[0]/5)+1,5,i+1)
    plt.title(b[i][0])
    plt.axis('off')
    plt.imshow(np.squeeze(a[i]))
    
plt.show()

# %%
b.shape
# Out:
# (85, 1)
