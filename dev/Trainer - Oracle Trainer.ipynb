# %%
from oracletrainer import OracleTrainer

# %%
ora = OracleTrainer('mnist', 'vgg16', 'mnistoracle123', './oracles/', lr = 0.0001, epochs = 50, 
                    batchsize = 50, earlystopping_patience = 3)
# Out:
# Model: "mnistoracle123"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_4 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  vgg16 (Functional)          (None, 1, 1, 512)         14714688
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# ...
# Total params: 14,715,201
# Trainable params: 14,715,201
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
#  41/186 [=====>........................] - ETA: 8s - loss: 0.0821 - accuracy: 0.9751
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 ora = OracleTrainer('mnist', 'vgg16', 'mnistoracle123', './oracles/', lr = 0.0001, epochs = 50,
# ...
