# %%
from gaaltrainer import GAALTrainer

# %%
generatorpath = './gans/mnist/generator_model_100.h5'
oraclepath = './oracles/mnist57.h5'
gaal = GAALTrainer('mnist', 'usps', generatorpath, oraclepath, n_samples_end = 50, start_samples = 25 , threshold = 1e-7, latent_dim = 100)
# Out:
# INFO:root:Loading dataset = usps
# Training on mnist, testing on usps
# WARNING:root:Please cite the following paper when using or referencing this Extra Keras Dataset:
# WARNING:root:Hull, J. J. (1994). A database for handwritten text recognition research. IEEE Transactions on pattern analysis and machine intelligence, 16(5), 550-554.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Classifier Accuracy Start: 0.9542048293089093
# Generating latents and adding new samples to labelled set.
# added 1
# added 2
# added 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 3>()
#       1 generatorpath = './gans/mnist/generator_model_100.h5'
#       2 oraclepath = './oracles/mnist57.h5'
# ----> 3 gaal = GAALTrainer('mnist', 'usps', generatorpath, oraclepath, n_samples_end = 50, start_samples = 25 , threshold = 1e-7, latent_dim = 100)
#
# File D:\Assignments\DSA5204\Project\gaaltrainer.py:82, in GAALTrainer.__init__(self, traindatasettype, testdatasettype, generatorpath, oraclepath, n_samples_end, threshold, start_samples, latent_dim)
#      80 self.generator = self.loadgenerator(generatorpath)
#      81 self.oracle = self.loadoracle(oraclepath)
# ---> 82 self.x_train_end, self.y_train_end, self.learner_acc_history, self.n_samples = self.traingaal(n_samples_end, self.x_train, self.y_train, self.x_test, self.y_test)
#
# File D:\Assignments\DSA5204\Project\gaaltrainer.py:190, in GAALTrainer.traingaal(self, n_samples_end, x_train, y_train, x_test, y_test)
#     187 with tf.GradientTape() as tape:
#     188     # Forward pass
#     189     tape.watch(z)
# --> 190     f = self.generator(z)
#     191     f = tf.reshape(f, [-1])
#     192     dot = tf.tensordot(f, w, 1) + b
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\engine\base_layer.py:1096, in Layer.__call__(self, *args, **kwargs)
#    1092   inputs = self._maybe_cast_inputs(inputs, input_list)
#    1094 with autocast_variable.enable_auto_cast_variables(
#    1095     self._compute_dtype_object):
# -> 1096   outputs = call_fn(inputs, *args, **kwargs)
#    1098 if self._activity_regularizer:
#    1099   self._handle_activity_regularization(inputs, outputs)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\utils\traceback_utils.py:92, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      90 bound_signature = None
#      91 try:
# ---> 92   return fn(*args, **kwargs)
#      93 except Exception as e:  # pylint: disable=broad-except
#      94   if hasattr(e, '_keras_call_info_injected'):
#      95     # Only inject info for the innermost failing call
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\engine\sequential.py:374, in Sequential.call(self, inputs, training, mask)
#     372   if not self.built:
#     373     self._init_graph_network(self.inputs, self.outputs)
# --> 374   return super(Sequential, self).call(inputs, training=training, mask=mask)
#     376 outputs = inputs  # handle the corner case where self.layers is empty
#     377 for layer in self.layers:
#     378   # During each iteration, `inputs` are the inputs to `layer`, and `outputs`
#     379   # are the outputs of `layer` applied to `inputs`. At the end of each
#     380   # iteration `inputs` is set to `outputs` to prepare for the next layer.
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\engine\functional.py:451, in Functional.call(self, inputs, training, mask)
#     432 @doc_controls.do_not_doc_inheritable
#     433 def call(self, inputs, training=None, mask=None):
#     434   """Calls the model on new inputs.
#     435
#     436   In this case `call` just reapplies
#    (...)
#     449       a list of tensors if there are more than one outputs.
#     450   """
# --> 451   return self._run_internal_graph(
#     452       inputs, training=training, mask=mask)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\engine\functional.py:589, in Functional._run_internal_graph(self, inputs, training, mask)
#     586   continue  # Node is not computable, try skipping.
#     588 args, kwargs = node.map_arguments(tensor_dict)
# --> 589 outputs = node.layer(*args, **kwargs)
#     591 # Update tensor_dict.
#     592 for x_id, y in zip(node.flat_output_ids, tf.nest.flatten(outputs)):
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\engine\base_layer.py:1096, in Layer.__call__(self, *args, **kwargs)
#    1092   inputs = self._maybe_cast_inputs(inputs, input_list)
#    1094 with autocast_variable.enable_auto_cast_variables(
#    1095     self._compute_dtype_object):
# -> 1096   outputs = call_fn(inputs, *args, **kwargs)
#    1098 if self._activity_regularizer:
#    1099   self._handle_activity_regularization(inputs, outputs)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\utils\traceback_utils.py:92, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      90 bound_signature = None
#      91 try:
# ---> 92   return fn(*args, **kwargs)
#      93 except Exception as e:  # pylint: disable=broad-except
#      94   if hasattr(e, '_keras_call_info_injected'):
#      95     # Only inject info for the innermost failing call
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\layers\core\dense.py:166, in Dense.call(self, inputs)
#     164 def call(self, inputs):
#     165   if inputs.dtype.base_dtype != self._compute_dtype_object.base_dtype:
# --> 166     inputs = tf.cast(inputs, dtype=self._compute_dtype_object)
#     168   is_ragged = isinstance(inputs, tf.RaggedTensor)
#     169   if is_ragged:
#     170     # In case we encounter a RaggedTensor with a fixed last dimension (last
#     171     # dimension not ragged), we can flatten the input and restore the ragged
#     172     # dimensions at the end.
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\util\dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1080 # Fallback dispatch system (dispatch v1):
#    1081 try:
# -> 1082   return dispatch_target(*args, **kwargs)
#    1083 except (TypeError, ValueError):
#    1084   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1085   # TypeError, when given unexpected types.  So we need to catch both.
#    1086   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\ops\math_ops.py:1000, in cast(x, dtype, name)
#     994   x = indexed_slices.IndexedSlices(values_cast, x.indices, x.dense_shape)
#     995 else:
#     996   # TODO(josh11b): If x is not already a Tensor, we could return
#     997   # ops.convert_to_tensor(x, dtype=dtype, ...)  here, but that
#     998   # allows some conversions that cast() can't do, e.g. casting numbers to
#     999   # strings.
# -> 1000   x = ops.convert_to_tensor(x, name="x")
#    1001   if x.dtype.base_dtype != base_type:
#    1002     x = gen_math_ops.cast(x, base_type, name=name)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\profiler\trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\framework\ops.py:1695, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1690       raise TypeError("convert_to_tensor did not convert to "
#    1691                       "the preferred dtype: %s vs %s " %
#    1692                       (ret.dtype.base_dtype, preferred_dtype.base_dtype))
#    1694 if ret is None:
# -> 1695   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1697 if ret is NotImplemented:
#    1698   continue
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:2098, in _dense_var_to_tensor(var, dtype, name, as_ref)
#    2097 def _dense_var_to_tensor(var, dtype=None, name=None, as_ref=False):
# -> 2098   return var._dense_var_to_tensor(dtype=dtype, name=name, as_ref=as_ref)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1476, in BaseResourceVariable._dense_var_to_tensor(***failed resolving arguments***)
#    1474   return self.read_value().op.inputs[0]
#    1475 else:
# -> 1476   return self.value()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:619, in BaseResourceVariable.value(self)
#     617   return self._cached_value
#     618 with ops.colocate_with(None, ignore_existing=True):
# --> 619   return self._read_variable_op()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:728, in BaseResourceVariable._read_variable_op(self)
#     726       result = read_and_set_handle()
#     727 else:
# --> 728   result = read_and_set_handle()
#     730 if not context.executing_eagerly():
#     731   # Note that if a control flow context is active the input of the read op
#     732   # might not actually be the handle. This line bypasses it.
#     733   tape.record_operation(
#     734       "ReadVariableOp", [result], [self.handle],
#     735       backward_function=lambda x: [x],
#     736       forward_function=lambda x: [x])
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:718, in BaseResourceVariable._read_variable_op.<locals>.read_and_set_handle()
#     717 def read_and_set_handle():
# --> 718   result = gen_resource_variable_ops.read_variable_op(
#     719       self.handle, self._dtype)
#     720   _maybe_set_handle_data(self._dtype, self.handle, result)
#     721   return result
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\ops\gen_resource_variable_ops.py:478, in read_variable_op(resource, dtype, name)
#     476 if tld.is_eager:
#     477   try:
# --> 478     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     479       _ctx, "ReadVariableOp", name, resource, "dtype", dtype)
#     480     return _result
#     481   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
plt.plot(gaal.n_samples, gaal.learner_acc_history)

# %%
# ?GAALTrainer
