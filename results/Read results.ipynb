# %%
import dill as pickle

# %%
with open('./result_gaal_uspsusps.pkl', 'rb') as file:
    result = pickle.load(file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 with open('./result_gaal_uspsusps.pkl', 'rb') as file:
#       2     result = pickle.load(file)
#
# FileNotFoundError: [Errno 2] No such file or directory: './result_gaal_uspsusps.pkl'

# %%
import matplotlib.pyplot as plt

# %%
plt.title(result[0])

for i in range(len(result[1])):
    plt.plot(result[2][i], result[1][i])
    
plt.ylabel('Accuracy')
plt.xlabel('Number of Labelled Samples')
plt.show()
